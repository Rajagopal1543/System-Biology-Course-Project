# %% [markdown]
# # Best case

# %%
import numpy as np
import random

def update_state(current_state, probability):
    return 1 if random.random() < probability else 0

def simulate_system(params, steps=100):
    states = {'O': 0, 'I': 1, 'L': 1, 'Li': 0, 'M': 0, 'P': 0}
    history = np.zeros((steps, 6))
    for t in range(steps):
        if t>1:
            if states['Li']==1:
                states['Li']=2
            if states['Li']==0:
                states['Li']=(-1)

        # if we have external lactose
        if states['L'] == 1:
            # internal lactose is on
            states['Li']=1
            # external lactose is off 
            states['L']=0

        # if lactose is on
        if states['I']==0:
            states['I']=-1
        if states['I']==1:
            states['I']=2
        if states['Li'] == 2 and t>1 and states['I']>0:
            # if lactose has been on for the last 2 epochs

                # update the status of Inhibitor based on probability of binding of lactose to inhibitor
            temp_state = update_state(states['I'], 1-params['lactose_binding'])
            if temp_state==1:
                states['I']=states['I']
            else:
                states['I']=0
        # if lactose is off  
        elif states['Li']==(-1) and t>1 and states['I']<1:
            #if inhibitor is off

                # update inhibitor status based on ability of inhibitor to operon
            temp_state = update_state(states['I'], params['lacI_binding'])
            if temp_state==0:
                states['I']=states['I']
            else:
                states['I']=1
            

        if states['O']==0:
            states['O']=(-1)
        elif states['O']==1:
            states['O']=2

        if states['I'] == 0 and t>1 and states['O']!=2:

            states['O']=1
        elif states['I']==2 and t>1 and states['O']>0:
            states['O']=0




        if states['M']==0:
            states['M']=(-1)
        if states['M']==1:
            states['M']=2
        if states['O']==2 and t>2:
            # if operon has been on for the last 2 epochs and mRNA is off
            if states['M']<=0:
                # update mRNA 
                temp_state = update_state(states['M'], params['mRNA_production_withoutinitialoperator'])
                if temp_state==0:
                    states['M']=states['M']
                else:
                    states['M']=1
            # if operon has been on for the last 2 epochs and mRNA is on
            elif states['M']>=1:
                # update mRNA, with a probability of degradation
                temp_state1 = update_state(states['M'], params['mRNA_production_withinitialoperator'])
                #temp_state2=update_state(states['M'], 1-params['mRNA_degradation_withoperator'])
                if temp_state1==1:
                    states['M']=2
                else:
                    states['M']=0

            # enough epochs has not passed for operon state change to have an impact 
        elif states['O']==1:
            states['M']=states['M']
        elif states['O']==0:
            states['M']=states['M']
        # if operon is off    
        elif states['O']==(-1):
            # if operon has been of for more than 2 epochs, and mRNA is still on
            if states['M']>=1:
                # update status of mRNA, with high degradation
                states['M']=update_state(states['M'],params['mRNA_degradation_withoutoperator'])
        elif t<=2:
            states['M']=0


        if states['P']==0:
            states['P']=(-1)
        if states['P']==1:
            states['P']=2
        # if mRNA is on
        if states['M']==2 and t>2:
            # if mRNA has been on for the last 2 epochs and protein is off
            if states['P']<=0:
                # update protein
                temp_state = update_state(states['P'], params['protein_production_withoutinitialprotein'])
                if temp_state==0:
                    states['P']=states['P']
                else:
                    states['P']=1
             # if mRNA has been on for the last 2 epochs and protein is on
            elif states['P']>=1:
                # update protein, with a probability of degradation
                temp_state1 = update_state(states['P'], params['protein_production_withinitialprotein'])
                #temp_state2=update_state(states['P'], 1-params['protein_degradation_withmRNA'])
                if temp_state1==1:
                    states['P']=2
                else:
                    states['P']=0
            # enough epochs has not passed for mRNA state change to have an impact 
        elif states['M']==1:
            states['P']=states['P']
        elif states['M']==0:
            states['P']=states['P']
        # if mRNA is off      
        elif states['M']==(-1):
            # if mRNA has been of for more than 2 epochs, and protein is still on
            if states['P']>=1:
                # update status of protein, with high degradation
                states['P']=update_state(states['P'],params['protein_degradation_withoutmRNA'])
        elif t<=2:
            states['P']=0


        # if protein is on
        #print(t,states['Li'])
        if states['P']==2 and t>2:
            # if protein has been of for more than 2 epochs, and lactose is still on
            if states['Li']>=1:
                # switch off lactose
                temp_state=update_state(states['Li'], 1-params['lactose_internalization'])
                if temp_state==1:
                    states['Li']=states['Li']
                else:
                    states['Li']=0
            else:
                if states['Li']<=0:
                    states['Li']=states['Li']
        elif t<=2:
            states['Li']=1

        #print(t,states['Li'])   

        history[t] = [states['O'], states['I'], states['L'], states['Li'], states['M'], states['P']]
        # if lactose is off
        if states['Li'] == (-1):
            # if lactose has been off for the last 3 epochs

                # try to bring in external lactose
            states['L']=update_state(states['L'], params['entry of lactose'])
            history[t][2]=states['L']
        
        
    return history
params = {
    'lacI_binding': 0.8,   # Probability LacI binds to Operon if free
    'lactose_binding': 0.8, # Probability lactose binds to LacI
    'lactose_internalization': 0.8,  # degradation of lactose by protein
   
    'mRNA_production_withoutinitialoperator': 0.8, # production of mRNA by operon if it has just become free
    'mRNA_production_withinitialoperator': 0.9, # production of mRNA by operon if it has been free for some time
    'mRNA_degradation_withoperator': 0.9, # mRNA stability if operon is free
    'mRNA_degradation_withoutoperator': 0.1, #mRNA stability is operon is off
    'protein_production_withoutinitialprotein': 0.8,  # production of protein by mRNA if it has just been transcribed 
    'protein_production_withinitialprotein': 0.9,  # production of protein by operon if it has been transcribed for some time
    'protein_degradation_withmRNA': 0.1, # protein stability if mRNA is being produced
    'protein_degradation_withoutmRNA': 0.1,  # protein stability is mRNA is not being produced
    'entry of lactose': 0.3 #entering of external lactose into the cell 

}
history=simulate_system(params,100)
from matplotlib import pyplot as plt
steps=len(history)
plt.figure(figsize=(20,10))


plt.subplot(6, 1, 1)
plt.step(range(steps), history[:,1], label='LacI', color='r', where='post')
plt.ylabel('LacI')

plt.title('Inhibitor')
plt.ylim(-1.1, 2.1)

plt.subplot(6, 1, 2)
plt.step(range(steps), history[:,2], label='Lactose', color='g', where='post')
plt.ylabel('External Lactose')
plt.title('External Lactose')
plt.ylim(-1.1, 2.1)

plt.subplot(6, 1, 3)
plt.step(range(steps), history[:,0], label='Operator', where='post')
plt.ylabel('Operator')
plt.title('Operator')
plt.ylim(-1.1, 2.1)

plt.subplot(6, 1, 4)
plt.step(range(steps), history[:,4], label='mRNA', color='b', where='post')
plt.ylabel('mRNA')
plt.title('mRNA')
plt.ylim(-1.1, 2.1)

plt.subplot(6, 1, 5)
plt.step(range(steps), history[:,5], label='Proteins', color='purple', where='post')
plt.ylabel('Proteins')
plt.title('Proteins')
plt.ylim(-1.1, 2.1)
plt.xlabel('Time Steps')

plt.subplot(6, 1, 6)
plt.step(range(steps), history[:,3], label='Li', color='brown', where='post')
plt.ylabel('Internal Lactose')
plt.title('Internal Lactose')
plt.ylim(-1.1, 2.1)
plt.xlabel('Time Steps')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Code

# %% [markdown]
# # Improvment: Loss Function for non -biological agrreing states

# %%
def custom_loss_function(history):
    loss = 0

    # Variables to keep track of the start of prolonged states
    last_high_end_lac = 0
    last_low_end_lac = 0
    last_high_end_op = 0
    last_low_end_op = 0
    last_high_end_mrna = 0
    last_low_end_mrna = 0
    last_high_end_pro = 0
    last_low_end_pro = 0
    # Threshold for prolonged states
    threshold = 4
    threshold_inhib=8
    

    for t in range(2, len(history)):
        #if history[t][1]==2 and history[t-1][1]==2 and history[t][0]>=1:
            #loss+=1
        
        '''if history[t][0] == 2 and history[t][4] < 0:
            loss += 1
        if history[t][4] == 2 and history[t][5] < 0:
            loss += 1
        if history[t][3] > 0 and history[t][2] == 1:
            loss += 1'''
        
        if history[t][0] == 2:
            if last_high_end_op==0:
                last_high_end_op=t
                   
            elif t > last_high_end_op + threshold:  # Start of a new high period
       
                loss += 1 
                #print('lac',last_high_end_lac,t)
        
        elif history[t][0] == -1:
            if last_low_end_op==0:
                last_low_end_op=t # Start of a new low period
            
            elif t > last_low_end_op + threshold:  
                loss += 1  # Penalize the start of a prolonged low period
                #print('lac',last_low_end_lac,t)

        # Reset on normal levels
        if history[t][0] not in [2, -1]:
            last_high_end_op = 0
            last_low_end_op = 0
            
            
        if history[t][1]==2:
            if history[t][3]==2:
                loss+=10
        if history[t][5]==2:
            if history[t][3]==2:
                loss+=10
        # 'Internal Lactose'
        if history[t][3] == 2:
            if last_high_end_lac==0:
                last_high_end_lac=t
                   
            elif t > last_high_end_lac + threshold:  # Start of a new high period
       
                loss += 1 
                #print('lac',last_high_end_lac,t)

        elif history[t][3] == -1:
            if last_low_end_lac==0:
                last_low_end_lac=t # Start of a new low period
            
            elif t > last_low_end_lac + threshold:  
                loss += 1  # Penalize the start of a prolonged low period
                #print('lac',last_low_end_lac,t)

        # Reset on normal levels
        if history[t][3] not in [2, -1]:
            last_high_end_lac = 0
            last_low_end_lac = 0
            
         # mRNA 
        if history[t][4] == 2:
            if last_high_end_mrna==0:
                last_high_end_mrna=t
                   
            elif t > last_high_end_mrna + threshold:  # Start of a new high period
       
                loss += 1 
                #print('mrna',last_high_end_mrna,t)

        elif history[t][4] == -1:
            if last_low_end_mrna==0:
                last_low_end_mrna=t # Start of a new low period
            
            elif t > last_low_end_mrna + threshold:  
                loss += 1  # Penalize the start of a prolonged low period
                #print('mrna',last_low_end_mrna,t)

        # Reset on normal levels
        if history[t][4] not in [2, -1]:
            last_high_end_mrna = 0
            last_low_end_mrna = 0
        
        
        # Protein
        if history[t][5] == 2:
            if last_high_end_pro==0:
                last_high_end_pro=t
                   
            elif t > last_high_end_pro + threshold:  # Start of a new high period
       
                loss += 1 
                #print('pro',last_high_end_pro,t)

        elif history[t][5] == -1:
            if last_low_end_pro==0:
                last_low_end_pro=t # Start of a new low period
            
            elif t > last_low_end_pro + threshold:  
                loss += 1  # Penalize the start of a prolonged low period
                #print('pro',last_low_end_pro,t)

        # Reset on normal levels
        if history[t][5] not in [2, -1]:
            last_high_end_pro = 0
            last_low_end_pro = 0


    return loss

# %%
import numpy as np
import random

def update_state(current_state, probability):
    return 1 if random.random() < probability else 0

def simulate_system(params, steps=100):
    states = {'O': 0, 'I': 1, 'L': 1, 'Li': 0, 'M': 0, 'P': 0}
    history = np.zeros((steps, 6))
    for t in range(steps):
        if t>1:
            if states['Li']==1:
                states['Li']=2
            if states['Li']==0:
                states['Li']=(-1)

        # if we have external lactose
        if states['L'] == 1:
            # internal lactose is on
            states['Li']=1
            # external lactose is off 
            states['L']=0

        # if lactose is on
        if states['I']==0:
            states['I']=-1
        if states['I']==1:
            states['I']=2
        if states['Li'] == 2 and t>1 and states['I']>0:
            # if lactose has been on for the last 2 epochs

                # update the status of Inhibitor based on probability of binding of lactose to inhibitor
            temp_state = update_state(states['I'], 1-params['lactose_binding'])
            if temp_state==1:
                states['I']=states['I']
            else:
                states['I']=0
        # if lactose is off  
        elif states['Li']==(-1) and t>1 and states['I']<1:
            #if inhibitor is off

                # update inhibitor status based on ability of inhibitor to operon
            temp_state = update_state(states['I'], params['lacI_binding'])
            if temp_state==0:
                states['I']=states['I']
            else:
                states['I']=1
            

        if states['O']==0:
            states['O']=(-1)
        elif states['O']==1:
            states['O']=2

        if states['I'] == 0 and t>1 and states['O']!=2:

            states['O']=1
        elif states['I']==2 and t>1 and states['O']>0:
            states['O']=0




        if states['M']==0:
            states['M']=(-1)
        if states['M']==1:
            states['M']=2
        if states['O']==2 and t>2:
            # if operon has been on for the last 2 epochs and mRNA is off
            if states['M']<=0:
                # update mRNA 
                temp_state = update_state(states['M'], params['mRNA_production_withoutinitialoperator'])
                if temp_state==0:
                    states['M']=states['M']
                else:
                    states['M']=1
            # if operon has been on for the last 2 epochs and mRNA is on
            elif states['M']>=1:
                # update mRNA, with a probability of degradation
                temp_state1 = update_state(states['M'], params['mRNA_production_withinitialoperator'])
                #temp_state2=update_state(states['M'], 1-params['mRNA_degradation_withoperator'])
                if temp_state1==1:
                    states['M']=2
                else:
                    states['M']=0

            # enough epochs has not passed for operon state change to have an impact 
        elif states['O']==1:
            states['M']=states['M']
        elif states['O']==0:
            states['M']=states['M']
        # if operon is off    
        elif states['O']==(-1):
            # if operon has been of for more than 2 epochs, and mRNA is still on
            if states['M']>=1:
                # update status of mRNA, with high degradation
                states['M']=update_state(states['M'],params['mRNA_degradation_withoutoperator'])
        elif t<=2:
            states['M']=0


        if states['P']==0:
            states['P']=(-1)
        if states['P']==1:
            states['P']=2
        # if mRNA is on
        if states['M']==2 and t>2:
            # if mRNA has been on for the last 2 epochs and protein is off
            if states['P']<=0:
                # update protein
                temp_state = update_state(states['P'], params['protein_production_withoutinitialprotein'])
                if temp_state==0:
                    states['P']=states['P']
                else:
                    states['P']=1
             # if mRNA has been on for the last 2 epochs and protein is on
            elif states['P']>=1:
                # update protein, with a probability of degradation
                temp_state1 = update_state(states['P'], params['protein_production_withinitialprotein'])
                #temp_state2=update_state(states['P'], 1-params['protein_degradation_withmRNA'])
                if temp_state1==1:
                    states['P']=2
                else:
                    states['P']=0
            # enough epochs has not passed for mRNA state change to have an impact 
        elif states['M']==1:
            states['P']=states['P']
        elif states['M']==0:
            states['P']=states['P']
        # if mRNA is off      
        elif states['M']==(-1):
            # if mRNA has been of for more than 2 epochs, and protein is still on
            if states['P']>=1:
                # update status of protein, with high degradation
                states['P']=update_state(states['P'],params['protein_degradation_withoutmRNA'])
        elif t<=2:
            states['P']=0


        # if protein is on
        #print(t,states['Li'])
        if states['P']==2 and t>2:
            # if protein has been of for more than 2 epochs, and lactose is still on
            if states['Li']>=1:
                # switch off lactose
                temp_state=update_state(states['Li'], 1-params['lactose_internalization'])
                if temp_state==1:
                    states['Li']=states['Li']
                else:
                    states['Li']=0
            else:
                if states['Li']<=0:
                    states['Li']=states['Li']
        elif t<=2:
            states['Li']=1

        #print(t,states['Li'])   

        history[t] = [states['O'], states['I'], states['L'], states['Li'], states['M'], states['P']]
        # if lactose is off
        if states['Li'] == (-1):
            # if lactose has been off for the last 3 epochs

                # try to bring in external lactose
            states['L']=update_state(states['L'], params['entry of lactose'])
            history[t][2]=states['L']
        
        
    return history

# %%
import numpy as np
import random
bu_li=[]

# try to simulate simulated annealing
def simulated_annealing(initial_params, simulate_system, custom_loss_function, iterations=1000, temp_initial=200.0, cooling_rate=0.99, perturbation_scale=0.1):
    current_params = initial_params.copy()
    current_history = simulate_system(current_params)
    current_loss = custom_loss_function(current_history)
    best_params = current_params.copy()
    best_loss = current_loss
    temp = temp_initial

    for i in range(iterations):
        
        candidate_params = {}
        for key, value in current_params.items():
            perturbation = np.random.normal(0.1,0.05*perturbation_scale*temp)
            if random.random()<0.5:
                
                candidate_params[key] = np.clip(value + perturbation, 0.1, 0.9)
            else:
                candidate_params[key] = np.clip(value - perturbation, 0.1, 0.9)

        candidate_history = simulate_system(candidate_params)
        candidate_loss = custom_loss_function(candidate_history)
        print(i,candidate_loss)
        # We calculate the acceptance probability
        if candidate_loss < current_loss:
            acceptance_prob = 1.0
        else:
            acceptance_prob = np.exp((current_loss - candidate_loss) / temp)

        # Now, we decide whether to accept the candidate
        if random.random() < acceptance_prob:
            current_params, current_loss = candidate_params, candidate_loss
            if candidate_loss < best_loss:
                best_params, best_loss = candidate_params, candidate_loss
        bu_li.append(current_loss)
        # Cool down
        temp *= cooling_rate

        print(f"Iteration {i}: Current Loss = {current_loss}, Temperature = {temp}")

    return best_params, best_loss



# Example usage
initial_params = {
    'lacI_binding': 0.2,
    'lactose_binding': 0.2,
    'lactose_internalization': 0.8,
    'mRNA_production_withoutinitialoperator': 0.8,
    'mRNA_production_withinitialoperator': 0.9,
    'protein_production_withoutinitialprotein': 0.1,
    'protein_production_withinitialprotein': 0.1,
 
    'mRNA_degradation_withoutoperator': 0.1,

    'protein_degradation_withoutmRNA': 0.1,
    'entry of lactose': 0.3
}
optimized_params, optimized_loss = simulated_annealing(initial_params, simulate_system, custom_loss_function)
print("Optimized Parameters:", optimized_params)
print("Optimized Loss:", optimized_loss)
# Out:
# 0 209
# Iteration 0: Current Loss = 209, Temperature = 198.0
# 1 296
# Iteration 1: Current Loss = 296, Temperature = 196.02
# 2 336
# Iteration 2: Current Loss = 336, Temperature = 194.0598
# 3 243
# Iteration 3: Current Loss = 243, Temperature = 192.119202
# 4 288
# Iteration 4: Current Loss = 288, Temperature = 190.19800998
# Iteration 905: Current Loss = 35, Temperature = 0.022208350399110708
# 906 108
# Iteration 906: Current Loss = 35, Temperature = 0.0219862668951196
# 907 76
# Iteration 907: Current Loss = 35, Temperature = 0.021766404226168403
# 908 63
# Iteration 908: Current Loss = 35, Temperature = 0.02154874018390672
# 909 75
# Iteration 909: Current Loss = 35, Temperature = 0.021333252782067654
# 910 72
# Iteration 910: Current Loss = 35, Temperature = 0.021119920254246978
# 911 154
# Iteration 911: Current Loss = 35, Temperature = 0.020908721051704507
# 912 75
# Iteration 912: Current Loss = 35, Temperature = 0.020699633841187462
# 913 86
# Iteration 913: Current Loss = 35, Temperature = 0.020492637502775586
# 914 132
# Iteration 914: Current Loss = 35, Temperature = 0.02028771112774783
# 915 143
# Iteration 915: Current Loss = 35, Temperature = 0.020084834016470352
# 916 76
# Iteration 916: Current Loss = 35, Temperature = 0.019883985676305647
# 917 65
# Iteration 917: Current Loss = 35, Temperature = 0.01968514581954259
# 918 132
# Iteration 918: Current Loss = 35, Temperature = 0.019488294361347164
# 919 97
# Iteration 919: Current Loss = 35, Temperature = 0.01929341141773369
# 920 104
# Iteration 920: Current Loss = 35, Temperature = 0.019100477303556355
# 921 49
# Iteration 921: Current Loss = 35, Temperature = 0.01890947253052079
# 922 93
# Iteration 922: Current Loss = 35, Temperature = 0.01872037780521558
# 923 103
# Iteration 923: Current Loss = 35, Temperature = 0.018533174027163427
# 924 130
# Iteration 924: Current Loss = 35, Temperature = 0.01834784228689179
# 925 95
# Iteration 925: Current Loss = 35, Temperature = 0.018164363864022873
# 926 125
# Iteration 926: Current Loss = 35, Temperature = 0.017982720225382644
# 927 61
# Iteration 927: Current Loss = 35, Temperature = 0.01780289302312882
# 928 101
# Iteration 928: Current Loss = 35, Temperature = 0.01762486409289753
# 929 152
# Iteration 929: Current Loss = 35, Temperature = 0.017448615451968554
# 930 115
# Iteration 930: Current Loss = 35, Temperature = 0.017274129297448867
# 931 124
# Iteration 931: Current Loss = 35, Temperature = 0.017101388004474378
# 932 109
# Iteration 932: Current Loss = 35, Temperature = 0.016930374124429635
# 933 99
# Iteration 933: Current Loss = 35, Temperature = 0.016761070383185337
# 934 94
# Iteration 934: Current Loss = 35, Temperature = 0.016593459679353485
# 935 120
# Iteration 935: Current Loss = 35, Temperature = 0.01642752508255995
# 936 141
# Iteration 936: Current Loss = 35, Temperature = 0.016263249831734352
# 937 94
# Iteration 937: Current Loss = 35, Temperature = 0.016100617333417007
# 938 109
# Iteration 938: Current Loss = 35, Temperature = 0.015939611160082835
# 939 119
# Iteration 939: Current Loss = 35, Temperature = 0.015780215048482007
# 940 116
# Iteration 940: Current Loss = 35, Temperature = 0.015622412897997186
# 941 71
# Iteration 941: Current Loss = 35, Temperature = 0.015466188769017213
# 942 80
# Iteration 942: Current Loss = 35, Temperature = 0.015311526881327042
# 943 85
# Iteration 943: Current Loss = 35, Temperature = 0.01515841161251377
# 944 148
# Iteration 944: Current Loss = 35, Temperature = 0.015006827496388634
# 945 109
# Iteration 945: Current Loss = 35, Temperature = 0.014856759221424747
# 946 105
# Iteration 946: Current Loss = 35, Temperature = 0.0147081916292105
# 947 151
# Iteration 947: Current Loss = 35, Temperature = 0.014561109712918395
# 948 83
# Iteration 948: Current Loss = 35, Temperature = 0.014415498615789212
# 949 114
# Iteration 949: Current Loss = 35, Temperature = 0.01427134362963132
# 950 171
# Iteration 950: Current Loss = 35, Temperature = 0.014128630193335007
# 951 83
# Iteration 951: Current Loss = 35, Temperature = 0.013987343891401657
# 952 122
# Iteration 952: Current Loss = 35, Temperature = 0.01384747045248764
# 953 122
# Iteration 953: Current Loss = 35, Temperature = 0.013708995747962763
# 954 112
# Iteration 954: Current Loss = 35, Temperature = 0.013571905790483134
# 955 139
# Iteration 955: Current Loss = 35, Temperature = 0.013436186732578303
# 956 147
# Iteration 956: Current Loss = 35, Temperature = 0.01330182486525252
# 957 59
# Iteration 957: Current Loss = 35, Temperature = 0.013168806616599993
# 958 109
# Iteration 958: Current Loss = 35, Temperature = 0.013037118550433994
# 959 100
# Iteration 959: Current Loss = 35, Temperature = 0.012906747364929654
# 960 151
# Iteration 960: Current Loss = 35, Temperature = 0.012777679891280357
# 961 64
# Iteration 961: Current Loss = 35, Temperature = 0.012649903092367553
# 962 93
# Iteration 962: Current Loss = 35, Temperature = 0.012523404061443878
# 963 98
# Iteration 963: Current Loss = 35, Temperature = 0.012398170020829439
# 964 92
# Iteration 964: Current Loss = 35, Temperature = 0.012274188320621144
# 965 121
# Iteration 965: Current Loss = 35, Temperature = 0.012151446437414932
# 966 156
# Iteration 966: Current Loss = 35, Temperature = 0.012029931973040782
# 967 136
# Iteration 967: Current Loss = 35, Temperature = 0.011909632653310374
# 968 140
# Iteration 968: Current Loss = 35, Temperature = 0.011790536326777271
# 969 121
# Iteration 969: Current Loss = 35, Temperature = 0.011672630963509498
# 970 170
# Iteration 970: Current Loss = 35, Temperature = 0.011555904653874403
# 971 135
# Iteration 971: Current Loss = 35, Temperature = 0.011440345607335659
# 972 105
# Iteration 972: Current Loss = 35, Temperature = 0.011325942151262302
# 973 94
# Iteration 973: Current Loss = 35, Temperature = 0.011212682729749679
# 974 49
# Iteration 974: Current Loss = 35, Temperature = 0.011100555902452182
# 975 94
# Iteration 975: Current Loss = 35, Temperature = 0.01098955034342766
# 976 97
# Iteration 976: Current Loss = 35, Temperature = 0.010879654839993383
# 977 106
# Iteration 977: Current Loss = 35, Temperature = 0.010770858291593449
# 978 69
# Iteration 978: Current Loss = 35, Temperature = 0.010663149708677514
# 979 69
# Iteration 979: Current Loss = 35, Temperature = 0.010556518211590739
# 980 160
# Iteration 980: Current Loss = 35, Temperature = 0.010450953029474831
# 981 95
# Iteration 981: Current Loss = 35, Temperature = 0.010346443499180083
# 982 77
# Iteration 982: Current Loss = 35, Temperature = 0.010242979064188282
# 983 107
# Iteration 983: Current Loss = 35, Temperature = 0.0101405492735464
# 984 159
# Iteration 984: Current Loss = 35, Temperature = 0.010039143780810935
# 985 87
# Iteration 985: Current Loss = 35, Temperature = 0.009938752343002826
# 986 207
# Iteration 986: Current Loss = 35, Temperature = 0.009839364819572798
# 987 145
# Iteration 987: Current Loss = 35, Temperature = 0.00974097117137707
# 988 147
# Iteration 988: Current Loss = 35, Temperature = 0.009643561459663299
# 989 60
# Iteration 989: Current Loss = 35, Temperature = 0.009547125845066666
# 990 84
# Iteration 990: Current Loss = 35, Temperature = 0.009451654586616
# 991 106
# Iteration 991: Current Loss = 35, Temperature = 0.009357138040749838
# 992 143
# Iteration 992: Current Loss = 35, Temperature = 0.00926356666034234
# 993 90
# Iteration 993: Current Loss = 35, Temperature = 0.009170930993738917
# 994 72
# Iteration 994: Current Loss = 35, Temperature = 0.009079221683801528
# 995 64
# Iteration 995: Current Loss = 35, Temperature = 0.008988429466963512
# 996 99
# Iteration 996: Current Loss = 35, Temperature = 0.008898545172293876
# 997 51
# Iteration 997: Current Loss = 35, Temperature = 0.008809559720570938
# 998 89
# Iteration 998: Current Loss = 35, Temperature = 0.008721464123365228
# 999 165
# Iteration 999: Current Loss = 35, Temperature = 0.008634249482131576
# Optimized Parameters: {'lacI_binding': 0.7564203498802283, 'lactose_binding': 0.9, 'lactose_internalization': 0.9, 'mRNA_production_withoutinitialoperator': 0.6077166615283238, 'mRNA_production_withinitialoperator': 0.6080100381235403, 'protein_production_withoutinitialprotein': 0.7642589740188438, 'protein_production_withinitialprotein': 0.6483357160150158, 'mRNA_degradation_withoutoperator': 0.4697376634035123, 'protein_degradation_withoutmRNA': 0.5996762929586529, 'entry of lactose': 0.8799828709185561}
# Optimized Loss: 35

# %% [markdown]
# # Visualize the final function

# %%
import numpy as np
import random

def update_state(current_state, probability):
    return 1 if random.random() < probability else 0

def simulate_system(params, steps=100):
    states = {'O': 0, 'I': 1, 'L': 1, 'Li': 0, 'M': 0, 'P': 0}
    history = np.zeros((steps, 6))
    for t in range(steps):
        if t>1:
            if states['Li']==1:
                states['Li']=2
            if states['Li']==0:
                states['Li']=(-1)

        # if we have external lactose
        if states['L'] == 1:
            # internal lactose is on
            states['Li']=1
            # external lactose is off 
            states['L']=0

        # if lactose is on
        if states['I']==0:
            states['I']=-1
        if states['I']==1:
            states['I']=2
        if states['Li'] == 2 and t>1 and states['I']>0:
            # if lactose has been on for the last 2 epochs

                # update the status of Inhibitor based on probability of binding of lactose to inhibitor
            temp_state = update_state(states['I'], 1-params['lactose_binding'])
            if temp_state==1:
                states['I']=states['I']
            else:
                states['I']=0
        # if lactose is off  
        elif states['Li']==(-1) and t>1 and states['I']<1:
            #if inhibitor is off

                # update inhibitor status based on ability of inhibitor to operon
            temp_state = update_state(states['I'], params['lacI_binding'])
            if temp_state==0:
                states['I']=states['I']
            else:
                states['I']=1
            

        if states['O']==0:
            states['O']=(-1)
        elif states['O']==1:
            states['O']=2

        if states['I'] == 0 and t>1 and states['O']!=2:

            states['O']=1
        elif states['I']==2 and t>1 and states['O']>0:
            states['O']=0




        if states['M']==0:
            states['M']=(-1)
        if states['M']==1:
            states['M']=2
        if states['O']==2 and t>2:
            # if operon has been on for the last 2 epochs and mRNA is off
            if states['M']<=0:
                # update mRNA 
                temp_state = update_state(states['M'], params['mRNA_production_withoutinitialoperator'])
                if temp_state==0:
                    states['M']=states['M']
                else:
                    states['M']=1
            # if operon has been on for the last 2 epochs and mRNA is on
            elif states['M']>=1:
                # update mRNA, with a probability of degradation
                temp_state1 = update_state(states['M'], params['mRNA_production_withinitialoperator'])
                #temp_state2=update_state(states['M'], 1-params['mRNA_degradation_withoperator'])
                if temp_state1==1:
                    states['M']=2
                else:
                    states['M']=0

            # enough epochs has not passed for operon state change to have an impact 
        elif states['O']==1:
            states['M']=states['M']
        elif states['O']==0:
            states['M']=states['M']
        # if operon is off    
        elif states['O']==(-1):
            # if operon has been of for more than 2 epochs, and mRNA is still on
            if states['M']>=1:
                # update status of mRNA, with high degradation
                states['M']=update_state(states['M'],params['mRNA_degradation_withoutoperator'])
        elif t<=2:
            states['M']=0


        if states['P']==0:
            states['P']=(-1)
        if states['P']==1:
            states['P']=2
        # if mRNA is on
        if states['M']==2 and t>2:
            # if mRNA has been on for the last 2 epochs and protein is off
            if states['P']<=0:
                # update protein
                temp_state = update_state(states['P'], params['protein_production_withoutinitialprotein'])
                if temp_state==0:
                    states['P']=states['P']
                else:
                    states['P']=1
             # if mRNA has been on for the last 2 epochs and protein is on
            elif states['P']>=1:
                # update protein, with a probability of degradation
                temp_state1 = update_state(states['P'], params['protein_production_withinitialprotein'])
                #temp_state2=update_state(states['P'], 1-params['protein_degradation_withmRNA'])
                if temp_state1==1:
                    states['P']=2
                else:
                    states['P']=0
            # enough epochs has not passed for mRNA state change to have an impact 
        elif states['M']==1:
            states['P']=states['P']
        elif states['M']==0:
            states['P']=states['P']
        # if mRNA is off      
        elif states['M']==(-1):
            # if mRNA has been of for more than 2 epochs, and protein is still on
            if states['P']>=1:
                # update status of protein, with high degradation
                states['P']=update_state(states['P'],params['protein_degradation_withoutmRNA'])
        elif t<=2:
            states['P']=0


        # if protein is on
        #print(t,states['Li'])
        if states['P']==2 and t>2:
            # if protein has been of for more than 2 epochs, and lactose is still on
            if states['Li']>=1:
                # switch off lactose
                temp_state=update_state(states['Li'], 1-params['lactose_internalization'])
                if temp_state==1:
                    states['Li']=states['Li']
                else:
                    states['Li']=0
            else:
                if states['Li']<=0:
                    states['Li']=states['Li']
        elif t<=2:
            states['Li']=1

        #print(t,states['Li'])   

        history[t] = [states['O'], states['I'], states['L'], states['Li'], states['M'], states['P']]
        # if lactose is off
        if states['Li'] == (-1):
            # if lactose has been off for the last 3 epochs

                # try to bring in external lactose
            states['L']=update_state(states['L'], params['entry of lactose'])
            history[t][2]=states['L']
        
        
    return history
history=simulate_system(optimized_params,100)
from matplotlib import pyplot as plt
steps=len(history)
plt.figure(figsize=(20,10))


plt.subplot(6, 1, 1)
plt.step(range(steps), history[:,1], label='LacI', color='r', where='post')
plt.ylabel('LacI')

plt.title('Inhibitor')
plt.ylim(-1.1, 2.1)

plt.subplot(6, 1, 2)
plt.step(range(steps), history[:,2], label='Lactose', color='g', where='post')
plt.ylabel('External Lactose')
plt.title('External Lactose')
plt.ylim(-1.1, 2.1)

plt.subplot(6, 1, 3)
plt.step(range(steps), history[:,0], label='Operator', where='post')
plt.ylabel('Operator')
plt.title('Operator')
plt.ylim(-1.1, 2.1)

plt.subplot(6, 1, 4)
plt.step(range(steps), history[:,4], label='mRNA', color='b', where='post')
plt.ylabel('mRNA')
plt.title('mRNA')
plt.ylim(-1.1, 2.1)

plt.subplot(6, 1, 5)
plt.step(range(steps), history[:,5], label='Proteins', color='purple', where='post')
plt.ylabel('Proteins')
plt.title('Proteins')
plt.ylim(-1.1, 2.1)
plt.xlabel('Time Steps')

plt.subplot(6, 1, 6)
plt.step(range(steps), history[:,3], label='Li', color='brown', where='post')
plt.ylabel('Internal Lactose')
plt.title('Internal Lactose')
plt.ylim(-1.1, 2.1)
plt.xlabel('Time Steps')
plt.savefig("output after second iteration of loss function.png")
plt.tight_layout()
plt.show()

# %%
optimized_params
# Out:
# {'lacI_binding': 0.7564203498802283,
#  'lactose_binding': 0.9,
#  'lactose_internalization': 0.9,
#  'mRNA_production_withoutinitialoperator': 0.6077166615283238,
#  'mRNA_production_withinitialoperator': 0.6080100381235403,
#  'protein_production_withoutinitialprotein': 0.7642589740188438,
#  'protein_production_withinitialprotein': 0.6483357160150158,
#  'mRNA_degradation_withoutoperator': 0.4697376634035123,
#  'protein_degradation_withoutmRNA': 0.5996762929586529,
#  'entry of lactose': 0.8799828709185561}

# %%
import numpy as np
import random

def update_state(current_state, probability):
    return 1 if random.random() < probability else 0

def simulate_system(params, steps=100):
    states = {'O': 0, 'I': 1, 'L': 1, 'Li': 0, 'M': 0, 'P': 0}
    history = np.zeros((steps, 6))
    for t in range(steps):
        if t>1:
            if states['Li']==1:
                states['Li']=2
            if states['Li']==0:
                states['Li']=(-1)

        # if we have external lactose
        if states['L'] == 1:
            # internal lactose is on
            states['Li']=1
            # external lactose is off 
            states['L']=0

        # if lactose is on
        if states['I']==1:
            states['I']=2
        if states['Li'] == 2 and t>1:
            # if lactose has been on for the last 2 epochs

                # update the status of Inhibitor based on probability of binding of lactose to inhibitor
            states['I'] = update_state(states['I'], 1-params['lactose_binding'])
        # if lactose is off  
        elif states['Li']==(-1) and states['I']<1:
            #if inhibitor is off

                # update inhibitor status based on ability of inhibitor to operon
            states['I'] = update_state(states['I'], params['lacI_binding'])

        if states['O']==0:
            states['O']=(-1)
        elif states['O']==1:
            states['O']=2

        if states['I'] == 0 and t>1 and states['O']!=2:

            states['O']=1
        elif states['I']==2 and t>1 and states['O']>0:
            states['O']=0




        if states['M']==0:
            states['M']=(-1)
        if states['O']==2 and t>2:
            # if operon has been on for the last 2 epochs and mRNA is off
            if states['M']<=0:
                # update mRNA 
                temp_state = update_state(states['M'], params['mRNA_production_withoutinitialoperator'])
                if temp_state==0:
                    states['M']=states['M']
                else:
                    states['M']=1
            # if operon has been on for the last 2 epochs and mRNA is on
            elif states['M']>=1:
                # update mRNA, with a probability of degradation
                temp_state1 = update_state(states['M'], params['mRNA_production_withinitialoperator'])
                #temp_state2=update_state(states['M'], 1-params['mRNA_degradation_withoperator'])
                if temp_state1==1:
                    states['M']=2
                else:
                    states['M']=0

            # enough epochs has not passed for operon state change to have an impact 
        elif states['O']==1:
            states['M']=states['M']
        elif states['O']==0:
            states['M']=states['M']
        # if operon is off    
        elif states['O']==(-1):
            # if operon has been of for more than 2 epochs, and mRNA is still on
            if states['M']>=1:
                # update status of mRNA, with high degradation
                states['M']=update_state(states['M'],params['mRNA_degradation_withoutoperator'])
        elif t<=2:
            states['M']=0


        if states['P']==0:
            states['P']=(-1)

        # if mRNA is on
        if states['M']==2 and t>2:
            # if mRNA has been on for the last 2 epochs and protein is off
            if states['P']<=0:
                # update protein
                temp_state = update_state(states['P'], params['protein_production_withoutinitialprotein'])
                if temp_state==0:
                    states['P']=states['P']
                else:
                    states['P']=1
             # if mRNA has been on for the last 2 epochs and protein is on
            elif states['P']>=1:
                # update protein, with a probability of degradation
                temp_state1 = update_state(states['P'], params['protein_production_withinitialprotein'])
                #temp_state2=update_state(states['P'], 1-params['protein_degradation_withmRNA'])
                if temp_state1==1:
                    states['P']=2
                else:
                    states['P']=0
            # enough epochs has not passed for mRNA state change to have an impact 
        elif states['M']==1:
            states['P']=states['P']
        elif states['M']==0:
            states['P']=states['P']
        # if mRNA is off      
        elif states['M']==(-1):
            # if mRNA has been of for more than 2 epochs, and protein is still on
            if states['P']>=1:
                # update status of protein, with high degradation
                states['P']=update_state(states['P'],params['protein_degradation_withoutmRNA'])
        elif t<=2:
            states['P']=0


        # if protein is on
        #print(t,states['Li'])
        if states['P']==2 and t>2:
            # if protein has been of for more than 2 epochs, and lactose is still on
            if states['Li']>=1:
                # switch off lactose
                temp_state=update_state(states['Li'], 1-params['lactose_internalization'])
                if temp_state==1:
                    states['Li']=states['Li']
                else:
                    states['Li']=0
            else:
                if states['Li']<=0:
                    states['Li']=states['Li']
        elif t<=2:
            states['Li']=1

        #print(t,states['Li'])   

        history[t] = [states['O'], states['I'], states['L'], states['Li'], states['M'], states['P']]
        # if lactose is off
        if states['Li'] == (-1):
            # if lactose has been off for the last 3 epochs

                # try to bring in external lactose
            states['L']=update_state(states['L'], params['entry of lactose'])
            history[t][2]=states['L']
        
        
    return history
history=simulate_system(initial_params,100)
from matplotlib import pyplot as plt
steps=len(history)
plt.figure(figsize=(20,10))


plt.subplot(6, 1, 1)
plt.step(range(steps), history[:,1], label='LacI', color='r', where='post')
plt.ylabel('LacI')

plt.title('Inhibitor')
plt.ylim(-1.1, 2.1)

plt.subplot(6, 1, 2)
plt.step(range(steps), history[:,2], label='Lactose', color='g', where='post')
plt.ylabel('External Lactose')
plt.title('External Lactose')
plt.ylim(-1.1, 2.1)

plt.subplot(6, 1, 3)
plt.step(range(steps), history[:,0], label='Operator', where='post')
plt.ylabel('Operator')
plt.title('Operator')
plt.ylim(-1.1, 2.1)

plt.subplot(6, 1, 4)
plt.step(range(steps), history[:,4], label='mRNA', color='b', where='post')
plt.ylabel('mRNA')
plt.title('mRNA')
plt.ylim(-1.1, 2.1)

plt.subplot(6, 1, 5)
plt.step(range(steps), history[:,5], label='Proteins', color='purple', where='post')
plt.ylabel('Proteins')
plt.title('Proteins')
plt.ylim(-1.1, 2.1)
plt.xlabel('Time Steps')

plt.subplot(6, 1, 6)
plt.step(range(steps), history[:,3], label='Li', color='brown', where='post')
plt.ylabel('Internal Lactose')
plt.title('Internal Lactose')
plt.ylim(-1.1, 2.1)
plt.xlabel('Time Steps')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Visualize loss

# %%
from matplotlib import pyplot as plt
len(bu_li)
plt.plot(bu_li)
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.title("Loss vs Iterations")
# Out:
# Text(0.5, 1.0, 'Loss vs Iterations')
